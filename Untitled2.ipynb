# %%
from imdb.caltech_imdb import caltech_imdb
from roidb import roidb
import cv2
import matplotlib.pyplot as plt

# %%
imdb2 = caltech_imdb('train', './data')
roidb.prepare_roidb(imdb2)
filtered = roidb.filter_roidb(imdb2.roidb)
# Out:
# [INFO - imdb]: train gt roidb loaded from ./train_gt_roidb.pkl
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# Bounding box invalid
# ...
